# %%
import pandas as pd

# %%
df = pd.read_csv('rape_rates-wide.csv')

# %%
df
# Out:
#                 State  2011   2012    2013   2014   2015   2016   2017
# 0      Andhra Pradesh  33.4  66.05   76.25   65.1   62.3   63.5   68.9
# 1   Arunachal Pradesh  12.4  33.67   47.68   57.4   62.1   58.7   53.4
# 2               Assam  36.9  89.54  113.93  123.4  148.2  131.3  143.6
# 3               Bihar   9.9  23.41   28.00   31.3   27.9   26.6   28.8
# 4        Chhattisgarh  16.5  34.38   56.28   31.3   44.8   45.9   61.1
# 5                 Goa   8.7  23.01   49.49   53.9   39.9   40.5   39.9
# 6             Gujarat  14.6  33.58   42.63   37.2   26.3   28.7   27.0
# 7             Haryana  21.7  50.31   75.04   73.0   75.7   77.8   88.7
# 8    Himachal Pradesh  14.5  27.13   43.61   44.4   37.4   35.2   35.7
# 9     Jammu & Kashmir  25.1  58.60   60.99   57.0   57.0   47.8   51.9
# 10          Jharkhand   9.5  29.16   41.26   37.4   40.2   33.2   35.6
# 11          Karnataka  15.7  34.92   40.11   46.0   41.6   45.8   45.2
# ...

# %%
pd.wide_to_long(df, i='State', j='Year',stubnames='').to_csv('rape_states-long.csv')

# %%
pd.read_csv('rape_states-long.csv')
# Out:
#                  State  Year  Unnamed: 2
# 0       Andhra Pradesh  2011        33.4
# 1    Arunachal Pradesh  2011        12.4
# 2                Assam  2011        36.9
# 3                Bihar  2011         9.9
# 4         Chhattisgarh  2011        16.5
# ..                 ...   ...         ...
# 219        Uttarakhand  2017        36.8
# 220        West Bengal  2017        67.3
# 221              Delhi  2017       133.3
# 222         all_states  2017        56.8
# 223              Total  2017        57.9
#
# [224 rows x 3 columns]
